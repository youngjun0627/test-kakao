# %%
import matplotlib.pyplot as plt
import numpy as np
import time

def create_random_skill(n):
    np.random.seed(42)
    grades = np.random.normal(40000, 20000, size=(n))
    grades = list(map(int, grades))
    return grades

def display():
    with open('output1.txt', 'r') as skills:
        skill = skills.read()
        skill = skill[4:-1].lstrip().rstrip()
        skill = list(map(float, skill.split(',')))
        
    mu, sigma = 40000, 20000
    s = np.array(skill)
    count, bins, ignored = plt.hist(s, 30, density=True)
    plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
                   np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
             linewidth=2, color='r')
    #plt.plot(y,x)
    plt.show()
    #print(s)

t = 0
while t<10:
    display()
    time.sleep(1)
    t+=1

# %%
np.random.seed(42)
mu, sigma = 40000, 20000
s = np.random.normal(mu,sigma, size=(30))
count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
                   np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
             linewidth=2, color='r')
#plt.plot(y,x)
plt.show()
print(s)
# Out:
# [49934.28306022 37234.71397658 52953.77076201 70460.59712816
#  35316.93250553 35317.26086102 71584.25631015 55348.69458306
#  30610.5122813  50851.20087172 30731.64614375 30685.40492859
#  44839.24543132  1734.39510684  5501.64334974 28754.24941518
#  19743.37759331 46284.94665191 21839.51848958 11753.92597329
#  69312.97537843 35484.47399027 41350.56409376 11505.03627573
#  29112.3455095  42218.4517942  16980.12845155 47513.96036691
#  27987.22620162 34166.12500413]
